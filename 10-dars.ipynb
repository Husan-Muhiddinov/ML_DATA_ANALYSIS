# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.arange(10)
plt.plot(data)
plt.show()

# %%
fig = plt.figure()
print(fig)

ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(data)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax3.plot(np.random.standard_normal(50).cumsum(), color="red", linestyle="dashed")
ax4 = fig.add_subplot(2, 2, 4)
# Out:
# Figure(640x480)

# %%
fig = plt.figure()
print(fig)

ax1 = fig.add_subplot(2, 2, 1)
ax1.hist(np.random.standard_normal(100), bins=20, color="green")

ax2 = fig.add_subplot(2, 2, 2)
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.standard_normal(30))

ax3 = fig.add_subplot(2, 2, 3)
ax3.plot(np.random.standard_normal(50).cumsum(), color="red", linestyle="dashed")

ax4 = fig.add_subplot(2, 2, 4)
# Out:
# Figure(640x480)

# %%
fig, axes = plt.subplots(2, 3)
fig.subplots_adjust(left=2, right=4)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.standard_normal(500), bins=50,
                        color="black", alpha=0.5)
fig.subplots_adjust(wspace=0, hspace=0)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(np.random.standard_normal(30).cumsum(), color="black",
         linestyle="dashed", marker="o");

# %%
fig = plt.figure()

ax = fig.add_subplot()

data = np.random.standard_normal(30).cumsum()

ax.plot(data, color="black", linestyle="dashed", label="Default");
ax.plot(data, color="black", linestyle="dashed",
         drawstyle="steps-post", label="steps-post");
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum());
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xlabel("Stages")
ax.set_title("My first matplotlib plot")
# Out:
# Text(0.5, 1.0, 'My first matplotlib plot')

# %%
fig, ax = plt.subplots()
ax.plot(np.random.standard_normal(1000).cumsum());

labels = ax.set_xticklabels(["one", "two", "three", "four", "five"], rotation=30, fontsize=8)
ax.set_xlabel("Stages")
ax.set_title("My first matplotlib plot")
# Out:
# C:\Users\muxitdinov_h.INTERNET\AppData\Local\Temp\ipykernel_143556\3626875551.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   labels = ax.set_xticklabels(["one", "two", "three", "four", "five"], rotation=30, fontsize=8)
# Text(0.5, 1.0, 'My first matplotlib plot')

# %%
fig, ax = plt.subplots()

ax.plot(np.random.randn(1000).cumsum(), color="black", label="one");
ax.plot(np.random.randn(1000).cumsum(), color="black", linestyle="dashed",label="two");
ax.plot(np.random.randn(1000).cumsum(), color="black", linestyle="dotted", label="three");
ax.set_title("My Legend matplotlib plot")
ax.legend()
